# %%
# !pip install qiskit

# %%
import qiskit as qk
qc = qk.QuantumCircuit(1)
initial_state = [0,1]   # Definir o estado inicial como |1>
qc.initialize(initial_state, 0) # Aplicar o estado inicial |1> ao Qubit 0
qc.draw()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-834a323249bc> in <module>()
# ----> 1 import qiskit as qk
#       2 qc = qk.QuantumCircuit(1)
#       3 initial_state = [0,1]   # Definir o estado inicial como |1>
#       4 qc.initialize(initial_state, 0) # Aplicar o estado inicial |1> ao Qubit 0
#       5 qc.draw()
#
# ModuleNotFoundError: No module named 'qiskit'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
